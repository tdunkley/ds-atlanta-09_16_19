# %%
thor2_cast = ["chris hemsworth", "natalie portman", "tom hiddleston", "kat dennings", "anthony hopkins", "idris elba"]
ragnarok_cast = ["chris hemsworth", "tom hiddleston","tessa thompson","cate blanchett","mark_ruffalo","anthony hopkins","karl urban","jeff goldblum"]

# %%
thor2_cast
# Out:
# ['chris hemsworth',
#  'natalie portman',
#  'tom hiddleston',
#  'kat dennings',
#  'anthony hopkins',
#  'idris elba']

# %%
ragnarok_cast
# Out:
# ['chris hemsworth',
#  'tom hiddleston',
#  'tessa thompson',
#  'cate blanchett',
#  'mark_ruffalo',
#  'anthony hopkins',
#  'karl urban',
#  'jeff goldblum']

# %%
list((set(thor2_cast) & set(ragnarok_cast)))
# Out:
# ['anthony hopkins', 'chris hemsworth', 'tom hiddleston']

# %%
if set(thor2_cast) & set(ragnarok_cast): print (list((set(thor2_cast) & set(ragnarok_cast))))
# Out:
# ['anthony hopkins', 'chris hemsworth', 'tom hiddleston']

# %%
def lower_dict(d):
   new_dict = dict((k.lower(), v.lower()) for k, v in d.items())
   return new_dict
a = {'Foo': "Hello", 'Bar': "World"}
print(lower_dict(a))
# Out:
# {'foo': 'hello', 'bar': 'world'}

# %%
import requests
macbeth = requests.get('http://www.gutenberg.org/cache/epub/2264/pg2264.txt').text

print(type(macbeth))
print(len(macbeth))
print(macbeth[:10000])
# Out:
# <class 'str'>
# 120253
# ﻿
#
# ***The Project Gutenberg's Etext of Shakespeare's First Folio***
# ********************The Tragedie of Macbeth*********************
#
#
#
# *******************************************************************
# THIS EBOOK WAS ONE OF PROJECT GUTENBERG'S EARLY FILES PRODUCED AT A
# TIME WHEN PROOFING METHODS AND TOOLS WERE NOT WELL DEVELOPED. THERE
# IS AN IMPROVED EDITION OF THIS TITLE WHICH MAY BE VIEWED AS EBOOK
# (#1533) at https://www.gutenberg.org/ebooks/1533
# *******************************************************************
#
#
#
# This is our 3rd edition of most of these plays.  See the index.
#
#
# Copyright laws are changing all over the world, be sure to check
# the copyright laws for your country before posting these files!!
#
# Please take a look at the important information in this header.
# We encourage you to keep this file on your own disk, keeping an
# electronic path open for the next readers.  Do not remove this.
#
#
# ...

# %%
import re


test = macbeth

test1 = test.split(' ')
test1

test2 = list(map(lambda x: re.sub('[^A-Za-z0-9]+', '',x), test1))
test2
#test3 = map(lambda x:x.lower(),test2)
#test3

#test3

#test1 = test.replace('*','')

#for i in (1,range(1,len(test1))):
#    re.sub('[^A-Za-z0-9]+', '', test1[i])

#test2 = test1.lower()
#test2

#import re

#re.sub('[^A-Za-z0-9]+', '', test1)

#import re
#re.sub('[^A-Za-z0-9]+', '', test1)

#test2 = test1.replace("'",'')
#test
#test.split(' ')
#dtest = {word}

#dict(zip(test,range(len(test))))
#dict(map(reversed, enumerate(test.split(' '))))

#dict = {key: i for i, key in enumerate(test.split(' '))}

####################################################################

#d = ({x:y for x,y in enumerate(test1.split(),0)})
#d1 = d


#d1.keys()
#d1.values()

#d2 = 




#t = {}
#for i in range(1,len(d1)):
#    t[i]
#    #d1.update.lower()
#    #print (i,d1[i].lower())

    
    

    
    
#   print (d1.values())
    


#index = range(0,len(d))
#index

#d1[903]

#d = {"index":index, "word":}

#print (macbeth[:500])
# Out:
# ['The',
#  'Project',
#  'Gutenbergs',
#  'Etext',
#  'of',
#  'Shakespeares',
#  'First',
#  'FolioThe',
#  'Tragedie',
#  'of',
#  'MacbethTHIS',
#  'EBOOK',
#  'WAS',
#  'ONE',
#  'OF',
#  'PROJECT',
#  'GUTENBERGS',
#  'EARLY',
#  'FILES',
#  'PRODUCED',
#  'AT',
#  'ATIME',
#  'WHEN',
#  'PROOFING',
#  'METHODS',
#  'AND',
#  'TOOLS',
#  'WERE',
#  'NOT',
#  'WELL',
#  'DEVELOPED',
#  'THEREIS',
#  'AN',
#  'IMPROVED',
#  'EDITION',
#  'OF',
#  'THIS',
#  'TITLE',
#  'WHICH',
#  'MAY',
#  'BE',
#  'VIEWED',
#  'AS',
#  'EBOOK1533',
#  'at',
#  'httpswwwgutenbergorgebooks1533This',
#  'is',
#  'our',
#  '3rd',
#  'edition',
#  'of',
#  'most',
#  'of',
#  'these',
#  'plays',
#  '',
#  'See',
#  'the',
#  'indexCopyright',
#  'laws',
#  'are',
#  'changing',
#  'all',
#  'over',
#  'the',
#  'world',
#  'be',
#  'sure',
#  'to',
#  'checkthe',
#  'copyright',
#  'laws',
#  'for',
#  'your',
#  'country',
#  'before',
#  'posting',
#  'these',
#  'filesPlease',
#  'take',
#  'a',
# ...

# %%
test1 = test.lower()
test2 = test1.split(' ')
count = {}

for i in test2:
    count[i] = count.get(i, 0) + 1

count
# Out:
# {'\ufeff\r\n\r\n***the': 1,
#  'project': 25,
#  "gutenberg's": 4,
#  'etext': 20,
#  'of': 397,
#  "shakespeare's": 6,
#  'first': 18,
#  'folio***\r\n********************the': 2,
#  'tragedie': 6,
#  'macbeth*********************\r\n\r\n\r\n\r\n*******************************************************************\r\nthis': 1,
#  'ebook': 1,
#  'was': 39,
#  'one': 29,
#  'early': 1,
#  'files': 1,
#  'produced': 1,
#  'at': 50,
#  'a\r\ntime': 2,
#  'when': 28,
#  'proofing': 2,
#  'methods': 1,
#  'and': 426,
#  'tools': 1,
#  'were': 34,
#  'not': 145,
#  'well': 11,
#  'developed.': 1,
#  'there\r\nis': 1,
#  'an': 28,
#  'improved': 1,
#  'edition': 3,
#  'this': 117,
#  'title': 2,
#  'which': 45,
#  'may': 40,
#  'be': 137,
#  'viewed': 1,
#  'as': 71,
#  'ebook\r\n(#1533)': 1,
#  'https://www.gutenberg.org/ebooks/1533\r\n*******************************************************************\r\n\r\n\r\n\r\nthis': 1,
#  'is': 187,
#  'our': 118,
#  '3rd': 1,
#  'most': 26,
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "//anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3325, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-154-b478a6fd18e5>", line 1, in <module>
#     import pandas as pd
#   File "//anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 42, in <module>
#     from pandas.core.api import *
#   File "//anaconda3/lib/python3.7/site-packages/pandas/core/api.py", line 26, in <module>
#     from pandas.core.groupby import Grouper
#   File "//anaconda3/lib/python3.7/site-packages/pandas/core/groupby/__init__.py", line 1, in <module>
#     from pandas.core.groupby.groupby import GroupBy  # noqa: F401
#   File "//anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py", line 37, in <module>
#     from pandas.core.frame import DataFrame
# ...
