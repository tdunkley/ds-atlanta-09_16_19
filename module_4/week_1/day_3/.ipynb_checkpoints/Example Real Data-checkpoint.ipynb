# %% [markdown]
# ## Real World Example
# [Dataset](https://data.world/exercises/linear-regression-exercise-1)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('cancer_reg.csv')
df.head().T
# Out:
#                                                  0  \
# avganncount                                   1397
# avgdeathsperyear                               469
# target_deathrate                             164.9
# incidencerate                                489.8
# medincome                                    61898
# popest2015                                  260131
# povertypercent                                11.2
# studypercap                                499.748
# binnedinc                        (61494.5, 125635]
# medianage                                     39.3
# medianagemale                                 36.9
# medianagefemale                               41.7
# geography                Kitsap County, Washington
# percentmarried                                52.5
# pctnohs18_24                                  11.5
# pcths18_24                                    39.5
# pctsomecol18_24                               42.1
# pctbachdeg18_24                                6.9
# pcths25_over                                  23.2
# pctbachdeg25_over                             19.6
# pctemployed16_over                            51.9
# pctunemployed16_over                             8
# pctprivatecoverage                            75.1
# pctprivatecoveragealone                        NaN
# pctempprivcoverage                            41.6
# pctpubliccoverage                             32.9
# pctpubliccoveragealone                          14
# pctwhite                                   81.7805
# pctblack                                   2.59473
# pctasian                                   4.82186
# pctotherrace                               1.84348
# pctmarriedhouseholds                       52.8561
# birthrate                                  6.11883
#
#                                                    1  \
# avganncount                                      173
# avgdeathsperyear                                  70
# target_deathrate                               161.3
# incidencerate                                  411.6
# medincome                                      48127
# popest2015                                     43269
# povertypercent                                  18.6
# studypercap                                  23.1112
# binnedinc                         (48021.6, 51046.4]
# medianage                                         33
# medianagemale                                   32.2
# medianagefemale                                 33.7
# geography                Kittitas County, Washington
# percentmarried                                  44.5
# pctnohs18_24                                     6.1
# pcths18_24                                      22.4
# pctsomecol18_24                                   64
# pctbachdeg18_24                                  7.5
# pcths25_over                                      26
# pctbachdeg25_over                               22.7
# pctemployed16_over                              55.9
# pctunemployed16_over                             7.8
# pctprivatecoverage                              70.2
# pctprivatecoveragealone                         53.8
# pctempprivcoverage                              43.6
# pctpubliccoverage                               31.1
# pctpubliccoveragealone                          15.3
# pctwhite                                     89.2285
# pctblack                                    0.969102
# pctasian                                     2.24623
# pctotherrace                                 3.74135
# pctmarriedhouseholds                         45.3725
# birthrate                                     4.3331
#
#                                                     2  \
# avganncount                                       102
# avgdeathsperyear                                   50
# target_deathrate                                174.7
# incidencerate                                   349.7
# medincome                                       49348
# popest2015                                      21026
# povertypercent                                   14.6
# studypercap                                   47.5602
# binnedinc                          (48021.6, 51046.4]
# medianage                                          45
# medianagemale                                      44
# medianagefemale                                  45.8
# geography                Klickitat County, Washington
# percentmarried                                   54.2
# pctnohs18_24                                       24
# pcths18_24                                       36.6
# pctsomecol18_24                                   NaN
# pctbachdeg18_24                                   9.5
# pcths25_over                                       29
# pctbachdeg25_over                                  16
# pctemployed16_over                               45.9
# pctunemployed16_over                                7
# pctprivatecoverage                               63.7
# pctprivatecoveragealone                          43.5
# pctempprivcoverage                               34.9
# pctpubliccoverage                                42.1
# pctpubliccoveragealone                           21.1
# pctwhite                                      90.9222
# pctblack                                     0.739673
# pctasian                                     0.465898
# pctotherrace                                  2.74736
# pctmarriedhouseholds                          54.4449
# birthrate                                     3.72949
#
#                                                 3                           4
# avganncount                                   427                          57
# avgdeathsperyear                              202                          26
# target_deathrate                            194.8                       144.4
# incidencerate                               430.4                       350.1
# medincome                                   44243                       49955
# popest2015                                  75882                       10321
# povertypercent                               17.1                        12.5
# studypercap                               342.637                           0
# binnedinc                        (42724.4, 45201]          (48021.6, 51046.4]
# medianage                                    42.8                        48.3
# medianagemale                                42.2                        47.8
# medianagefemale                              43.4                        48.9
# geography                Lewis County, Washington  Lincoln County, Washington
# percentmarried                               52.7                        57.8
# pctnohs18_24                                 20.2                        14.9
# pcths18_24                                   41.2                          43
# pctsomecol18_24                              36.1                          40
# pctbachdeg18_24                               2.5                           2
# pcths25_over                                 31.6                        33.4
# pctbachdeg25_over                             9.3                          15
# pctemployed16_over                           48.3                        48.2
# pctunemployed16_over                         12.1                         4.8
# pctprivatecoverage                           58.4                        61.6
# pctprivatecoveragealone                      40.3                        43.9
# pctempprivcoverage                             35                        35.1
# pctpubliccoverage                            45.3                          44
# pctpubliccoveragealone                         25                        22.7
# pctwhite                                  91.7447                      94.104
# pctblack                                 0.782626                    0.270192
# pctasian                                  1.16136                     0.66583
# pctotherrace                              1.36264                    0.492135
# pctmarriedhouseholds                      51.0215                     54.0275
# birthrate                                 4.60384                     6.79666

# %%
X = df[['povertypercent','medincome','medianage','medianagemale','pctemployed16_over','pctunemployed16_over','pctprivatecoverage','pctprivatecoveragealone']]
X.head()
# Out:
#    povertypercent  medincome  medianage  medianagemale  pctemployed16_over  \
# 0            11.2      61898       39.3           36.9                51.9
# 1            18.6      48127       33.0           32.2                55.9
# 2            14.6      49348       45.0           44.0                45.9
# 3            17.1      44243       42.8           42.2                48.3
# 4            12.5      49955       48.3           47.8                48.2
#
#    pctunemployed16_over  pctprivatecoverage  pctprivatecoveragealone
# 0                   8.0                75.1                      NaN
# 1                   7.8                70.2                     53.8
# 2                   7.0                63.7                     43.5
# 3                  12.1                58.4                     40.3
# 4                   4.8                61.6                     43.9

# %%
y = df['avgdeathsperyear']

# %%
for col in X.columns:
    print((col, sum(X[col].isnull())))
# Out:
# ('povertypercent', 0)
# ('medincome', 0)
# ('medianage', 0)
# ('medianagemale', 0)
# ('pctemployed16_over', 152)
# ('pctunemployed16_over', 0)
# ('pctprivatecoverage', 0)
# ('pctprivatecoveragealone', 609)

# %% [markdown]
# ## Dealing With Null Values
# [missingpy](https://pypi.org/project/missingpy/)

# %%
from missingpy import MissForest
imputer = MissForest(max_iter=10)
X_imputed = imputer.fit_transform(X)
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4

# %%
col_names = ['povertypercent','medincome','medianage','medianagemale','pctemployed16_over','pctunemployed16_over','pctprivatecoverage','pctprivatecoveragealone']
x = pd.DataFrame(X_imputed, columns= col_names)

# %%
from sklearn import preprocessing
x = preprocessing.scale(x)

# %% [markdown]
# ## Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_features= PolynomialFeatures(degree=3,interaction_only=True, include_bias=True)
x_p = polynomial_features.fit_transform(x)

# %%
import statsmodels.api as sm
model = sm.OLS(y, x_p).fit()
ypred = model.predict(x_p)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       avgdeathsperyear   R-squared:                       0.265
# Model:                            OLS   Adj. R-squared:                  0.242
# Method:                 Least Squares   F-statistic:                     11.56
# Date:                Thu, 31 Oct 2019   Prob (F-statistic):          4.98e-137
# Time:                        10:39:01   Log-Likelihood:                -22816.
# No. Observations:                3047   AIC:                         4.582e+04
# Df Residuals:                    2954   BIC:                         4.638e+04
# Df Model:                          92
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const
# x55         -148.1746     69.231     -2.140      0.032    -283.921     -12.428
# x56          103.6177     78.052      1.328      0.184     -49.424     256.660
# x57            6.1422     25.730      0.239      0.811     -44.307      56.592
# x58         -148.8429    141.482     -1.052      0.293    -426.256     128.570
# x59           11.4772    185.003      0.062      0.951    -351.271     374.225
# x60          -65.9984    142.361     -0.464      0.643    -345.135     213.138
# x61          110.8467    453.646      0.244      0.807    -778.649    1000.342
# x62          -78.9954    448.608     -0.176      0.860    -958.612     800.621
# x63           59.3975     40.873      1.453      0.146     -20.745     139.540
# x64           85.1547     41.449      2.054      0.040       3.883     166.427
# x65           49.8400     73.190      0.681      0.496     -93.668     193.348
# x66          -70.6670     73.188     -0.966      0.334    -214.172      72.838
# x67           17.2584     36.731      0.470      0.638     -54.763      89.280
# x68          -28.0559     76.589     -0.366      0.714    -178.228     122.116
# x69          129.6094     73.673      1.759      0.079     -14.847     274.065
# x70         -148.1689    101.591     -1.458      0.145    -347.364      51.026
# x71          236.6574    102.437      2.310      0.021      35.803     437.512
# x72          -36.9971     29.914     -1.237      0.216     -95.651      21.657
# x73          -14.8918     64.040     -0.233      0.816    -140.459     110.675
# x74            8.9500     64.883      0.138      0.890    -118.271     136.171
# x75           16.8434     87.333      0.193      0.847    -154.396     188.083
# x76           23.5967    118.025      0.200      0.842    -207.824     255.017
# x77          -73.2021    116.952     -0.626      0.531    -302.517     156.113
# x78           75.3675    353.246      0.213      0.831    -617.265     768.000
# x79         -143.5811    359.878     -0.399      0.690    -849.218     562.056
# x80           61.7728    388.799      0.159      0.874    -700.571     824.117
# x81           -3.7600    500.741     -0.008      0.994    -985.597     978.077
# x82           45.6287    128.228      0.356      0.722    -205.797     297.054
# x83           30.8311     21.030      1.466      0.143     -10.403      72.065
# x84           14.3899     49.058      0.293      0.769     -81.801     110.581
# x85           19.5967     43.801      0.447      0.655     -66.286     105.479
# x86          -13.4993     41.858     -0.323      0.747     -95.573      68.574
# x87          -16.2691     57.135     -0.285      0.776    -128.298      95.760
# x88           -9.3036     24.850     -0.374      0.708     -58.028      39.421
# x89          -60.8417     52.323     -1.163      0.245    -163.435      41.752
# x90           84.2030     57.438      1.466      0.143     -28.419     196.825
# x91          -25.9395     28.331     -0.916      0.360     -81.490      29.610
# x92          -73.1078     19.645     -3.721      0.000    -111.628     -34.588
# ==============================================================================
# Omnibus:                     5367.780   Durbin-Watson:                   1.913
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9619846.742
# Skew:                          12.093   Prob(JB):                         0.00
# Kurtosis:                     277.202   Cond. No.                     1.74e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.74e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
MSE=sum((ypred-y)**2)/len(y)
print('MSE = ', MSE)
# Out:
# MSE =  186822.91683157967

# %% [markdown]
# ## Regularization
# [Statsmodel_Implementation](https://www.statsmodels.org/stable/generated/statsmodels.regression.linear_model.OLS.fit_regularized.html)

# %%
import statsmodels.api as sm
model = sm.OLS(y,x).fit_regularized(method='elastic_net', alpha=1.0, L1_wt=0.8)
ypred = model.predict(x)

# %%
regularized_regression_parameters = model.params
print(regularized_regression_parameters)
# Out:
# x1      0.000000
# x2    106.884080
# x3     -4.473559
# x4    -34.862059
# x5     30.052602
# x6     74.254708
# x7    -32.170321
# x8     20.473217
# dtype: float64

# %%
MSE=sum((ypred-y)**2)/len(y)
print('MSE = ', MSE)
# Out:
# MSE =  264698.727726802
