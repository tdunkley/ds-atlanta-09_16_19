# %% [markdown]
# ## Real World Example
# [Dataset](https://data.world/exercises/linear-regression-exercise-1)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('cancer_reg.csv')
df.head().T
# Out:
#                                                  0  \
# avganncount                                   1397
# avgdeathsperyear                               469
# target_deathrate                             164.9
# incidencerate                                489.8
# medincome                                    61898
# popest2015                                  260131
# povertypercent                                11.2
# studypercap                                499.748
# binnedinc                        (61494.5, 125635]
# medianage                                     39.3
# medianagemale                                 36.9
# medianagefemale                               41.7
# geography                Kitsap County, Washington
# percentmarried                                52.5
# pctnohs18_24                                  11.5
# pcths18_24                                    39.5
# pctsomecol18_24                               42.1
# pctbachdeg18_24                                6.9
# pcths25_over                                  23.2
# pctbachdeg25_over                             19.6
# pctemployed16_over                            51.9
# pctunemployed16_over                             8
# pctprivatecoverage                            75.1
# pctprivatecoveragealone                        NaN
# pctempprivcoverage                            41.6
# pctpubliccoverage                             32.9
# pctpubliccoveragealone                          14
# pctwhite                                   81.7805
# pctblack                                   2.59473
# pctasian                                   4.82186
# pctotherrace                               1.84348
# pctmarriedhouseholds                       52.8561
# birthrate                                  6.11883
#
#                                                    1  \
# avganncount                                      173
# avgdeathsperyear                                  70
# target_deathrate                               161.3
# incidencerate                                  411.6
# medincome                                      48127
# popest2015                                     43269
# povertypercent                                  18.6
# studypercap                                  23.1112
# binnedinc                         (48021.6, 51046.4]
# medianage                                         33
# medianagemale                                   32.2
# medianagefemale                                 33.7
# geography                Kittitas County, Washington
# percentmarried                                  44.5
# pctnohs18_24                                     6.1
# pcths18_24                                      22.4
# pctsomecol18_24                                   64
# pctbachdeg18_24                                  7.5
# pcths25_over                                      26
# pctbachdeg25_over                               22.7
# pctemployed16_over                              55.9
# pctunemployed16_over                             7.8
# pctprivatecoverage                              70.2
# pctprivatecoveragealone                         53.8
# pctempprivcoverage                              43.6
# pctpubliccoverage                               31.1
# pctpubliccoveragealone                          15.3
# pctwhite                                     89.2285
# pctblack                                    0.969102
# pctasian                                     2.24623
# pctotherrace                                 3.74135
# pctmarriedhouseholds                         45.3725
# birthrate                                     4.3331
#
#                                                     2  \
# avganncount                                       102
# avgdeathsperyear                                   50
# target_deathrate                                174.7
# incidencerate                                   349.7
# medincome                                       49348
# popest2015                                      21026
# povertypercent                                   14.6
# studypercap                                   47.5602
# binnedinc                          (48021.6, 51046.4]
# medianage                                          45
# medianagemale                                      44
# medianagefemale                                  45.8
# geography                Klickitat County, Washington
# percentmarried                                   54.2
# pctnohs18_24                                       24
# pcths18_24                                       36.6
# pctsomecol18_24                                   NaN
# pctbachdeg18_24                                   9.5
# pcths25_over                                       29
# pctbachdeg25_over                                  16
# pctemployed16_over                               45.9
# pctunemployed16_over                                7
# pctprivatecoverage                               63.7
# pctprivatecoveragealone                          43.5
# pctempprivcoverage                               34.9
# pctpubliccoverage                                42.1
# pctpubliccoveragealone                           21.1
# pctwhite                                      90.9222
# pctblack                                     0.739673
# pctasian                                     0.465898
# pctotherrace                                  2.74736
# pctmarriedhouseholds                          54.4449
# birthrate                                     3.72949
#
#                                                 3                           4
# avganncount                                   427                          57
# avgdeathsperyear                              202                          26
# target_deathrate                            194.8                       144.4
# incidencerate                               430.4                       350.1
# medincome                                   44243                       49955
# popest2015                                  75882                       10321
# povertypercent                               17.1                        12.5
# studypercap                               342.637                           0
# binnedinc                        (42724.4, 45201]          (48021.6, 51046.4]
# medianage                                    42.8                        48.3
# medianagemale                                42.2                        47.8
# medianagefemale                              43.4                        48.9
# geography                Lewis County, Washington  Lincoln County, Washington
# percentmarried                               52.7                        57.8
# pctnohs18_24                                 20.2                        14.9
# pcths18_24                                   41.2                          43
# pctsomecol18_24                              36.1                          40
# pctbachdeg18_24                               2.5                           2
# pcths25_over                                 31.6                        33.4
# pctbachdeg25_over                             9.3                          15
# pctemployed16_over                           48.3                        48.2
# pctunemployed16_over                         12.1                         4.8
# pctprivatecoverage                           58.4                        61.6
# pctprivatecoveragealone                      40.3                        43.9
# pctempprivcoverage                             35                        35.1
# pctpubliccoverage                            45.3                          44
# pctpubliccoveragealone                         25                        22.7
# pctwhite                                  91.7447                      94.104
# pctblack                                 0.782626                    0.270192
# pctasian                                  1.16136                     0.66583
# pctotherrace                              1.36264                    0.492135
# pctmarriedhouseholds                      51.0215                     54.0275
# birthrate                                 4.60384                     6.79666

# %%
X = df[['povertypercent','medincome','medianage','medianagemale','pctemployed16_over','pctunemployed16_over','pctprivatecoverage','pctprivatecoveragealone']]
X.head()
X.shape
# Out:
# 0.19986872333442732

# %%
y = df['avgdeathsperyear']

# %%
for col in X.columns:
    print((col, sum(X[col].isnull())))
# Out:
# ('povertypercent', 0)
# ('medincome', 0)
# ('medianage', 0)
# ('medianagemale', 0)
# ('pctemployed16_over', 152)
# ('pctunemployed16_over', 0)
# ('pctprivatecoverage', 0)
# ('pctprivatecoveragealone', 609)

# %% [markdown]
# ## Dealing With Null Values
# [missingpy](https://pypi.org/project/missingpy/)

# %%
from missingpy import MissForest
imputer = MissForest(max_iter=10)
X_imputed = imputer.fit_transform(X)
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5

# %%
col_names = ['povertypercent','medincome','medianage','medianagemale','pctemployed16_over','pctunemployed16_over','pctprivatecoverage','pctprivatecoveragealone']
x = pd.DataFrame(X_imputed, columns= col_names)

# %%
from sklearn import preprocessing
x = preprocessing.scale(x)

# %% [markdown]
# ## Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_features= PolynomialFeatures(degree=3,interaction_only=True, include_bias=True)
x_p = polynomial_features.fit_transform(x)

# %%
import statsmodels.api as sm
model = sm.OLS(y, x_p).fit()
ypred = model.predict(x_p)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       avgdeathsperyear   R-squared:                       0.264
# Model:                            OLS   Adj. R-squared:                  0.241
# Method:                 Least Squares   F-statistic:                     11.51
# Date:                Thu, 31 Oct 2019   Prob (F-statistic):          2.36e-136
# Time:                        12:09:51   Log-Likelihood:                -22817.
# No. Observations:                3047   AIC:                         4.582e+04
# Df Residuals:                    2954   BIC:                         4.638e+04
# Df Model:                          92
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const
# x56           97.2456     77.884      1.249      0.212     -55.467     249.958
# x57            6.4019     25.840      0.248      0.804     -44.264      57.068
# x58         -135.0064    139.872     -0.965      0.335    -409.263     139.250
# x59           27.8967    220.165      0.127      0.899    -403.796     459.589
# x60          -48.8629    138.969     -0.352      0.725    -321.349     223.623
# x61           77.7459    453.723      0.171      0.864    -811.898     967.390
# x62          -52.0651    460.286     -0.113      0.910    -954.578     850.448
# x63           55.9144     42.582      1.313      0.189     -27.578     139.407
# x64           79.7290     41.448      1.924      0.055      -1.541     160.999
# x65           48.9696     73.532      0.666      0.505     -95.209     193.148
# x66          -68.8132     74.680     -0.921      0.357    -215.244      77.618
# x67           18.8537     36.848      0.512      0.609     -53.397      91.105
# x68          -25.5122     76.667     -0.333      0.739    -175.838     124.814
# x69          124.9717     73.532      1.700      0.089     -19.207     269.150
# x70         -137.7508    101.423     -1.358      0.175    -336.618      61.116
# x71          224.8213    102.217      2.199      0.028      24.397     425.245
# x72          -37.2678     29.921     -1.246      0.213     -95.935      21.399
# x73          -20.5275     63.894     -0.321      0.748    -145.809     104.754
# x74           -0.8670     62.325     -0.014      0.989    -123.072     121.338
# x75           21.1809     87.551      0.242      0.809    -150.487     192.848
# x76           20.9751    120.579      0.174      0.862    -215.453     257.403
# x77          -66.9758    134.301     -0.499      0.618    -330.309     196.357
# x78          100.9051    350.817      0.288      0.774    -586.965     788.775
# x79         -179.4686    358.088     -0.501      0.616    -881.595     522.658
# x80           96.9233    379.080      0.256      0.798    -646.364     840.210
# x81          -65.4754    493.786     -0.133      0.895   -1033.674     902.723
# x82           43.7262    144.535      0.303      0.762    -239.674     327.127
# x83           30.3599     21.847      1.390      0.165     -12.477      73.197
# x84           12.6972     49.649      0.256      0.798     -84.653     110.048
# x85           22.7076     43.856      0.518      0.605     -63.284     108.699
# x86          -14.2564     41.917     -0.340      0.734     -96.447      67.934
# x87          -12.3766     58.162     -0.213      0.832    -126.418     101.665
# x88           -8.7977     26.378     -0.334      0.739     -60.518      42.923
# x89          -58.5635     52.067     -1.125      0.261    -160.655      43.528
# x90           82.7783     57.793      1.432      0.152     -30.540     196.097
# x91          -25.1329     28.441     -0.884      0.377     -80.900      30.634
# x92          -73.1955     19.644     -3.726      0.000    -111.713     -34.678
# ==============================================================================
# Omnibus:                     5379.334   Durbin-Watson:                   1.913
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9719354.917
# Skew:                          12.149   Prob(JB):                         0.00
# Kurtosis:                     278.618   Cond. No.                     1.74e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.74e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
MSE=sum((ypred-y)**2)/len(y)
print('MSE = ', MSE)
# Out:
# MSE =  187037.8490958749

# %% [markdown]
# ## Regularization
# [Statsmodel_Implementation](https://www.statsmodels.org/stable/generated/statsmodels.regression.linear_model.OLS.fit_regularized.html)

# %%
import statsmodels.api as sm
model = sm.OLS(y,x).fit_regularized(method='elastic_net', alpha=1.0, L1_wt=0.0)
ypred = model.predict(x)

# %%
regularized_regression_parameters = model.params
print(regularized_regression_parameters)
# Out:
# [-2.01801494  9.47003903 -1.0248997  -6.56098305  4.63145137  4.233208
#   1.38702849  4.8227606 ]

# %%
MSE=sum((ypred-y)**2)/len(y)
print('MSE = ', MSE)
# Out:
# MSE =  284197.33541865455
